# %%
print("Введите свое имя: ")
your_name = input()
print("Добро пожаловать на ФИПЛ, ", your_name)
print("Добро пожаловать на ФИПЛ, ", your_name.upper())
print("Добро пожаловать на ФИПЛ, ", your_name.lower())
# Out:
# Введите свое имя:
# Кирилл
# Добро пожаловать на ФИПЛ,  Кирилл
# Добро пожаловать на ФИПЛ,  КИРИЛЛ
# Добро пожаловать на ФИПЛ,  кирилл
